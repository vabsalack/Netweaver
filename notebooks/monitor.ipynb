# %%
from netweaver.utils import PlotTraining

# %%
plot = PlotTraining(
    path_batch_log="/home/USER_NETWEAVER/project_netweaver/notebooks/logs/model_training/model-20250515-092132/Log-batch-20250515-092132.csv",
    path_epoch_log="/home/USER_NETWEAVER/project_netweaver/notebooks/logs/model_training/model-20250515-092132/Log-epoch-20250515-092132.csv",
)

# %%
plot.live_plot()
# Out:
# /home/USER_NETWEAVER/project_netweaver/src/netweaver/utils.py:71: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   self.ani = FuncAnimation(self.fig, self._animate, interval=500, blit=True)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot.pause()

# %%
plot.resume()

# %%
plot.static_plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
