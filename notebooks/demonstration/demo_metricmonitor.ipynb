# %% [markdown]
# # Metrics Monitoring
#
# - The library automatically configures the appropriate matplotlib backend to `matplotlib.use("module://ipympl.backend_nbagg")` ensure live and interactive rendering of training metrics. By running matplotlib in a separate process and thread, the plots remain responsive and update in real time. For more details on the implementation, refer to the library's source code.

# %% [markdown]
# - Import the `PlotTraining` class from `netweaver.utils`.
#
# - Instantiate a `PlotTraining` object by providing the file paths for the epoch, batch, and validation log files.
# - This setup enables seamless visualization and monitoring of training metrics using the provided logs.

# %%
from netweaver.utils import PlotTraining

# %%
plot = PlotTraining(  # replace the params value with your training log paths
    path_epoch_log="/home/USER_NETWEAVER/project_netweaver/rough_room/logs/model_training/model-20250712-000347/Log-epoch-20250712-000347.csv",
    path_batch_log="/home/USER_NETWEAVER/project_netweaver/rough_room/logs/model_training/model-20250712-000347/Log-batch-20250712-000347.csv",
    path_validation_log="",
)

# %% [markdown]
# - The `live_plot` method reads the provided log files and dynamically updates a single graph for clear, real-time interpretation of training progress.
#
# - The plot displays:
#     - **x-axis:** Epochs
#     - **Left y-axis (1):** Loss values
#     - **Right y-axis (2):** Accuracy values
#     - **Right y-axis (3):** Learning rate values
# - This visualization enables easy monitoring of key training metrics as they evolve during the training process.

# %%
plot.live_plot(loss_caplimit=2)
# Out:
# /home/USER_NETWEAVER/project_netweaver/src/netweaver/utils.py:118: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   self.ani = FuncAnimation(self.fig, self._animate, interval=500, blit=True)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# - The `pause()` method temporarily halts the live animation of the training metrics plot, allowing you to inspect the current state of the graph without further updates. This is useful for detailed analysis or presentations.

# %%
plot.pause()

# %% [markdown]
# - The `resume()` method restarts the live animation of the training metrics plot, allowing real-time updates to continue after a pause. This is useful for resuming monitoring and visualization of training progress without losing context.

# %%
plot.resume()
# Out:
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''
# Error in _animate: [Errno 2] No such file or directory: ''

# %% [markdown]
# - Use the `static_plot()` method to generate a comprehensive visualization of all training metrics after training has completed.
#
# - This method is ideal for summarizing results and can also save the plot as an image file for reporting or further analysis.

# %%
plot.static_plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plot.static_plot()
#
# File ~/project_netweaver/src/netweaver/utils.py:241, in PlotTraining.static_plot(self, save_to_file)
#     236         (artist_lr,) = axes_lr.plot(
#     237             data_batch["xaxis_value"], data_batch["learning_rate"], label="LR decay", color="grey", alpha=1, linestyle="-", linewidth=2
#     238         )
#     240 if self.path_validation_log is not None:
# --> 241     data_validation = pd.read_csv(self.path_validation_log)
#     242     if not data_validation.empty:
#     243         (artist_vloss,) = axes_loss.plot(
#     244             data_validation["epoch"], data_validation["loss_validation"], label="Val Loss", color="blue", alpha=0.5, linewidth=2
#     245         )
#
# File ~/project_netweaver/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/project_netweaver/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/project_netweaver/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/project_netweaver/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/project_netweaver/.venv/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: ''
